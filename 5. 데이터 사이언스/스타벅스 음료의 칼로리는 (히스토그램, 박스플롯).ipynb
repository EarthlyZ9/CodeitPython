# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/starbucks_drinks.csv')
df
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 214  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 215  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 216  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 217  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 218  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
df.plot(kind = 'hist', y = 'Calories', bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind = 'box', y = 'Calories')
# Out:
# <AxesSubplot:>
