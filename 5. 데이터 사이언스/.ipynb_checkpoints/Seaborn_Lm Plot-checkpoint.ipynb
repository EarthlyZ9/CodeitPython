# %%
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/body.csv', index_col = 0)
body_df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
body_df.plot(kind='scatter', x = 'Height', y = 'Weight')

# %%
sns.lmplot(data = body_df, x = 'Height', y = 'Weight')

# %% [markdown]
# 회귀선: 흩어져 있는 점들을 하나의 선으로 표현
# 키가 x인 학생은 무게가 y일 거라고 예측 가능
# 점들이 꽤 흩어져 있어서 정확하지는 않음
