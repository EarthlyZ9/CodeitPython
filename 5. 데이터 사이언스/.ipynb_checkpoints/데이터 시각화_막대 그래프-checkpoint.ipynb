# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/sports.csv', index_col = 0)
df
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df.plot(kind = 'bar')

# %%
df.plot(kind = 'barh')

# %%
df.plot(kind = 'bar', stacked = True)

# %%
df['Female'].plot(kind='bar')
