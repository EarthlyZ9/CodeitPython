# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/movie_metadata.csv')
df
# Out:
#                                                   title    year  \
# 0                                               Avatar   2009.0
# 1             Pirates of the Caribbean: At World's End   2007.0
# 2                                              Spectre   2015.0
# 3                                The Dark Knight Rises   2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...     NaN
# ...                                                 ...     ...
# 5038                           Signed Sealed Delivered   2013.0
# 5039                         The Following                  NaN
# 5040                              A Plague So Pleasant   2013.0
# 5041                                  Shanghai Calling   2012.0
# 5042                                 My Date with Drew   2004.0
#
#                                genres           director          actor_1  \
# 0     Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# ...

# %%
drop_condition = df.sort_values(by = 'budget', ascending = False).head(15).index

# %%
df.drop(drop_condition, inplace = True)
df
# Out:
#                                                   title    year  \
# 0                                               Avatar   2009.0
# 2                                              Spectre   2015.0
# 3                                The Dark Knight Rises   2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...     NaN
# 5                                          John Carter   2012.0
# ...                                                 ...     ...
# 5038                           Signed Sealed Delivered   2013.0
# 5039                         The Following                  NaN
# 5040                              A Plague So Pleasant   2013.0
# 5041                                  Shanghai Calling   2012.0
# 5042                                 My Date with Drew   2004.0
#
#                                genres           director          actor_1  \
# 0     Action|Adventure|Fantasy|Sci-Fi      James Cameron      CCH Pounder
# ...
