# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/young_survey.csv')
df
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 992    5.0                       2.0    5.0   2.0      2.0              5.0
# 993    4.0                       4.0    5.0   1.0      3.0              4.0
# 994    4.0                       3.0    1.0   1.0      2.0              2.0
# 995    5.0                       3.0    3.0   3.0      1.0              3.0
# 996    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
df.corr()
# Out:
#                                Music  Slow songs or fast songs     Dance  \
# Music                       1.000000                  0.075426  0.066719
# Slow songs or fast songs    0.075426                  1.000000  0.188217
# Dance                       0.066719                  0.188217  1.000000
# Folk                        0.027648                 -0.062023  0.065863
# Country                    -0.014272                 -0.072138  0.055106
# ...                              ...                       ...       ...
# Spending on healthy eating  0.073037                 -0.027398  0.026210
# Age                        -0.078058                  0.010998  0.031215
# Height                     -0.068002                  0.106873 -0.012681
# Weight                     -0.128233                  0.125870  0.014024
# Number of siblings         -0.011585                  0.002352  0.003952
#
#                                 Folk   Country  Classical music   Musical  \
# ...

# %%
df.corr().loc['Getting up', 'Rock']
# Out:
# 0.10524522650834675

# %%
df.corr().loc['Getting up', 'Dance']
# Out:
# 0.027249283401199146

# %%
df.corr().loc['Getting up', 'Classical music']
# Out:
# 0.0142854764145847

# %%
df.corr().loc['Getting up', 'Opera']
# Out:
# -0.07181906916938091

# %%
df.corr().loc['Getting up', 'Swing, Jazz']
# Out:
# 0.019556469412842042

# %%
df2 = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/survey.csv')
df2
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0      5.0                       3.0    2.0   1.0      2.0              2.0
# 1      4.0                       4.0    2.0   1.0      1.0              1.0
# 2      5.0                       5.0    2.0   2.0      3.0              4.0
# 3      5.0                       3.0    2.0   1.0      1.0              1.0
# 4      5.0                       3.0    4.0   3.0      2.0              4.0
# ..     ...                       ...    ...   ...      ...              ...
# 992    5.0                       2.0    5.0   2.0      2.0              5.0
# 993    4.0                       4.0    5.0   1.0      3.0              4.0
# 994    4.0                       3.0    1.0   1.0      2.0              2.0
# 995    5.0                       3.0    3.0   3.0      1.0              3.0
# 996    5.0                       5.0    4.0   3.0      2.0              3.0
#
# ...

# %%
movie_genres = df2.loc[:, 'Horror':'Action']

# %%
sns.clustermap(movie_genres.corr())

# %%
titanic_df = pd.read_csv('/Users/ljs2000/PycharmProjects/CodeitPython/5. 데이터 사이언스/csv/titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic_df.sort_values(by = 'Fare', ascending = False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
titanic_df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic_df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic_df.plot(kind = 'scatter', x = 'Pclass', y = 'Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.kdeplot(titanic_df['Pclass'], titanic_df['Survived'])
# Out:
# /Users/ljs2000/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.stripplot(data = titanic_df, x = 'Survived', y = 'Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.violinplot(data=titanic_df, x = 'Survived', y = 'Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.stripplot(data = titanic_df, x = 'Survived', y = 'Age', hue = 'Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>
